# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nastia**
# student, e-com manager

# %% [markdown]
# *I am interested in data science because it can help me analize data in e-com sales*

# %% [markdown]
# ### My code is supposed to sum 1 and 1

# %%
1+1
# Out:
# 2

# %% [markdown]
# header1|header2|header3|
# ---|---|---|
# I|you|he|
# we|you|they
#
# 1. **want**
#     1. i
#     1. you
#     1. we
#     1. they
# 1. **wants**
#     1. he
#     1. she
#
# <div class="alert alert-block alert-success">
# <b>ATTENTION:</b> the weather is nice
# </div>
